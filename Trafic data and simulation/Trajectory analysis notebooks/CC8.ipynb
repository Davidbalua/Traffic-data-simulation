# %%
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# scenario 5 is based scenario generated by me: all are 3.5

# %%
#scenario 5 is based scenario generated by me: all are 3.5
vehicle_routes_scenario5 = pd.read_csv("data/Scenarios generated by me/CC8/GothaerPlatz_scenario5_allare3Point5.csv")
#change the vehicle type from number to name
vehicle_routes_scenario5['VEHTYPE'].replace(to_replace=[100, 150, 200, 300], value=["Car", "Transporter", "HGV", "Bus"],
                                            inplace=True)
vehicle_routes_filtered_scenario5 = vehicle_routes_scenario5[vehicle_routes_scenario5["$VEHICLE:NO"]<318]
max_accs_cars_scenario5= vehicle_routes_filtered_scenario5.groupby(["$VEHICLE:NO"]).max()

# %%
max_accs_cars_scenario5
# Out:
#               SIMTMOFDAY  SIMSEC     POS  POSLAT      VEHTYPE  SPEED  \
# $VEHICLE:NO
# 1            00:00:53.40    53.4  246.30    0.97          Car  53.73
# 2            00:00:47.80    47.8  247.22    1.00          Car  51.68
# 3            00:01:12.10    72.1  136.78    0.97  Transporter  41.61
# 4            00:01:01.70    61.7  219.92    0.50          Car  54.24
# 5            00:01:09.90    69.9  220.34    1.00          Car  53.05
# ...                  ...     ...     ...     ...          ...    ...
# 313          00:09:36.00   576.0  220.20    1.00  Transporter  42.04
# 314          00:09:37.30   577.3  220.35    1.00  Transporter  44.63
# 315          00:08:58.40   538.4  246.58    1.00          Car  58.20
# 316          00:09:37.00   577.0  246.93    0.50          HGV  34.30
# 317          00:09:01.50   541.5  246.47    1.00          Car  55.32
#
#              ACCELERATION  LANE\LINK\NO  LANE\INDEX
# $VEHICLE:NO
# 1                    2.67           128           3
# ...

# %%
# barchart with dictionary
vehicle_numbers = [i for i in range(1, 318)]
fig, ax = plt.subplots(figsize=(10, 10))
ax.bar(vehicle_numbers, max_accs_cars_scenario5["ACCELERATION"], label="Vehicle")
ax.set_title(
    label="Maximum acceleration of all vehicles from standstill position in the based scenario with the default CC8",
    color="red")
# draw CC8
x_coordinates = [0, 318]

y_coordinates = [3.5, 3.5]

ax.plot(x_coordinates, y_coordinates, color="red", label="CC8 Parameter")
ax.set_xlabel("Vehicle numbers", color="red")
ax.set_ylabel("Maximum Acceleration(m/s2)", color="red")
ax.tick_params(axis="both", length=15, direction="inout", color="blue", labelcolor="red")
ax.spines["bottom"].set_color("red")
ax.spines["left"].set_color("red")
# draw legends
ax.legend(loc="lower right", shadow="true", fancybox=True, title="Vehicle Number");
ax.grid("on", alpha=0.9)

# plt.savefig("data/CC8/Based_Scenario_by_me.png")
max_accs_cars_scenario5["ACCELERATION"].describe()
# Out:
# count    317.000000
# mean       1.941514
# std        0.905369
# min        0.000000
# 25%        1.580000
# 50%        2.050000
# 75%        2.670000
# max        3.290000
# Name: ACCELERATION, dtype: float64

# %% [markdown]
# scenario 3 cc8 = 10 and max and desired functions are 10

# %%
#scenario 3 cc8 = 10 and max and desired functions are 10
#change the vehicle type from number to name
vehicle_routes_scenario3 = pd.read_csv("data/Scenarios generated by me/CC8/GothaerPlatz_0_to_500_seconds_cc8_10.csv")
#change the vehicle type from number to name
vehicle_routes_scenario3['VEHTYPE'].replace(to_replace=[100, 150, 200, 300], value=["Car", "Transporter", "HGV", "Bus"],
                                            inplace=True)
max_accs_cars_scenario3 = vehicle_routes_scenario3.groupby(["$VEHICLE:NO"]).max()

fig, ax = plt.subplots(figsize=(10, 10))
ax.bar(vehicle_numbers, max_accs_cars_scenario3["ACCELERATION"], label="Vehicle")
ax.set_xlabel("Vehicle numbers", color="red")
ax.set_ylabel("Maximum Acceleration(m/s2)", color="red")
ax.set_title(
    label="Maximum acceleration of all vehicles from standstill position in the scenario with CC8 = 10 m/s2 and the maximum value of desired and maximum acceleration functions are 10 m/s2",
    color="red", fontsize = 8)
# draw default CC8
x_coordinates = [0, 318]
y_coordinates = [3.5, 3.5]

# draw CC8 10
x1_coordinates = [0, 318]
y1_coordinates = [10, 10]

ax.plot(x_coordinates, y_coordinates, color="red", label="Default CC8 Parameter")
ax.plot(x1_coordinates, y1_coordinates, color="green", label="Updated CC8 Parameter")
ax.tick_params(axis="both", length=15, direction="inout", color="blue", labelcolor="red")
ax.spines["bottom"].set_color("red")
ax.spines["left"].set_color("red")

# draw legends
ax.legend(loc="lower right", shadow="true", fancybox=True, title="Vehicle Number");
ax.grid("on", alpha=0.9)
# plt.savefig("data/CC8/cc8 10 and max and desired functions are 10.png")
max_accs_cars_scenario3["ACCELERATION"].describe()
# Out:
# count    317.000000
# mean       2.039085
# std        1.217399
# min        0.000000
# 25%        1.500000
# 50%        2.030000
# 75%        2.570000
# max        7.020000
# Name: ACCELERATION, dtype: float64

# %% [markdown]
# scenario 4 cc8 = 10 but max and desired functions are 3.5

# %%
#scenario 4 cc8 = 10 but max and desired functions are 3.5
#change the vehicle type from number to name
vehicle_routes_scenario4 = pd.read_csv("data/Scenarios generated by me/CC8/scenario4.csv")
#change the vehicle type from number to name
vehicle_routes_scenario4['VEHTYPE'].replace(to_replace=[100, 150, 200, 300], value=["Car", "Transporter", "HGV", "Bus"],
                                            inplace=True)

max_accs_cars_scenario4 = vehicle_routes_scenario4.groupby(["$VEHICLE:NO"]).max()

fig, ax = plt.subplots(figsize=(10, 10))
ax.bar(vehicle_numbers, max_accs_cars_scenario4["ACCELERATION"], label="Vehicle")
ax.set_xlabel("Vehicle numbers", color="red")
ax.set_ylabel("Maximum Acceleration(m/s2)", color="red")
ax.set_title(
    label="Maximum acceleration of all vehicles from standstill position in the scenario with CC8 = 10 m/s2 and the maximum value of desired and maximum acceleration functions are 3.5",
    color="red", fontsize = 8)
# draw default CC8
x_coordinates = [0, 318]
y_coordinates = [3.5, 3.5]

# draw CC8 10
x1_coordinates = [0, 318]
y1_coordinates = [10, 10]

ax.plot(x_coordinates, y_coordinates, color="red", label="Default CC8 Parameter")
ax.plot(x1_coordinates, y1_coordinates, color="green", label="Updated CC8 Parameter")
ax.tick_params(axis="both", length=15, direction="inout", color="blue", labelcolor="red")
ax.spines["bottom"].set_color("red")
ax.spines["left"].set_color("red")

# draw legends
ax.legend(loc="lower right", shadow="true", fancybox=True, title="Vehicle Number");
ax.grid("on", alpha=0.9)

# plt.savefig("data/CC8/cc8 10 but max and desired functions are 3Point5.png")

# %% [markdown]
# based scenario Marco

# %%
# base scenario

#change the vehicle type from number to name
vehicle_routes_based = pd.read_csv("data/Scenarios generated by Marco/GothaerPlatz - baseline.csv")
#change the vehicle type from number to name
vehicle_routes_based['VEHTYPE'].replace(to_replace=[100, 150, 200, 300], value=["Car", "Transporter", "HGV", "Bus"],
                                        inplace=True)
all_cars_on_link_54_based = vehicle_routes_based[
    (vehicle_routes_based["SIMSEC"] < 500) & (
            vehicle_routes_based["SIMSEC"] > 0)]

max_accs_cars_based = all_cars_on_link_54_based.groupby(["$VEHICLE:NO"]).max()

fig, ax = plt.subplots(figsize=(10, 10))
ax.bar(vehicle_numbers, max_accs_cars_based["ACCELERATION"], label="Vehicle")
ax.set_xlabel("Vehicle numbers", color="red")
ax.set_ylabel("Maximum Acceleration(m/s2)", color="red")
ax.set_title(
    label="Maximum acceleration of all vehicles from standstill position for the based scenario with unknown CC8 from 0 to 500 seconds",
    color="red")
# draw default CC8
x_coordinates = [0, 318]
y_coordinates = [3.5, 3.5]

ax.plot(x_coordinates, y_coordinates, color="red", label="Unknown CC8 Parameter")

ax.tick_params(axis="both", length=15, direction="inout", color="blue", labelcolor="red")
ax.spines["bottom"].set_color("red")
ax.spines["left"].set_color("red")

# draw legends
ax.legend(loc="lower right", shadow="true", fancybox=True, title="Vehicle Number");
ax.grid("on", alpha=0.9)

# plt.savefig("data/CC8/Based Scenario by marco.png")
# calculate statistacal values
max_accs_cars_based["ACCELERATION"].describe()
# Out:
# count    317.000000
# mean       1.868675
# std        0.918490
# min        0.000000
# 25%        1.430000
# 50%        2.080000
# 75%        2.600000
# max        3.290000
# Name: ACCELERATION, dtype: float64

# %% [markdown]
# Scenario 1 generated by marco

# %%
# scenario1
vehicle_routes_scenario1 = pd.read_csv("data/Scenarios generated by Marco/GothaerPlatz - Scenario 1.csv")
#change the vehicle type from number to name
vehicle_routes_scenario1['VEHTYPE'].replace(to_replace=[100, 150, 200, 300], value=["Car", "Transporter", "HGV", "Bus"],
                                            inplace=True)


all_cars_on_link_54_scenario1 = vehicle_routes_scenario1[
    (vehicle_routes_scenario1["SIMSEC"] < 500) & (
            vehicle_routes_scenario1["SIMSEC"] > 0)]

max_accs_cars_scenario1 = all_cars_on_link_54_scenario1.groupby(["$VEHICLE:NO"]).max()

fig, ax = plt.subplots(figsize=(10, 10))
ax.bar(vehicle_numbers, max_accs_cars_scenario1["ACCELERATION"], label="Vehicle")
ax.set_xlabel("Vehicle numbers", color="red")
ax.set_ylabel("Maximum Acceleration(m/s2)", color="red")
ax.set_title(
    label="Maximum acceleration of all vehicles from standstill position for scenario 1 with unknown CC8 from 0 to 500 seconds",
    color="red", fontsize = 8)
# draw default CC8
x_coordinates = [0, 318]
y_coordinates = [3.5, 3.5]

ax.plot(x_coordinates, y_coordinates, color="red", label="Unknown CC8 Parameter")

ax.tick_params(axis="both", length=15, direction="inout", color="blue", labelcolor="red")
ax.spines["bottom"].set_color("red")
ax.spines["left"].set_color("red")

# draw legends
ax.legend(loc="lower right", shadow="true", fancybox=True, title="Vehicle Number");
ax.grid("on", alpha=0.9)
# plt.savefig("data/CC8/Scenario 1 generated by marco.png")

# calculate statistacal values
max_accs_cars_scenario1["ACCELERATION"].describe()
# Out:
# count    317.000000
# mean       1.868644
# std        0.907795
# min        0.000000
# 25%        1.520000
# 50%        2.000000
# 75%        2.570000
# max        3.250000
# Name: ACCELERATION, dtype: float64

# %% [markdown]
# Scenario 2

# %%
# scenario2
vehicle_routes_scenario2 = pd.read_csv("data/Scenarios generated by Marco/GothaerPlatz - Scenario 2.csv")
#change the vehicle type from number to name
vehicle_routes_scenario2['VEHTYPE'].replace(to_replace=[100, 150, 200, 300], value=["Car", "Transporter", "HGV", "Bus"],
                                            inplace=True)

all_cars_on_link_54_scenario2 = vehicle_routes_scenario2[
    (vehicle_routes_scenario2["SIMSEC"] < 500) & (
            vehicle_routes_scenario2["SIMSEC"] > 0)]

max_accs_cars_scenario2 = all_cars_on_link_54_scenario2.groupby(["$VEHICLE:NO"]).max()

fig, ax = plt.subplots(figsize=(10, 10))
ax.bar(vehicle_numbers, max_accs_cars_scenario2["ACCELERATION"], label="Vehicle")
ax.set_xlabel("Vehicle numbers", color="red")
ax.set_ylabel("Maximum Acceleration(m/s2)", color="red")
ax.set_title(
    label="Maximum acceleration of all vehicles from standstill position for scenario 2 with unknown CC8 from 0 to 500 seconds",
    color="red")
# draw default CC8
x_coordinates = [0, 318]
y_coordinates = [3.5, 3.5]

ax.plot(x_coordinates, y_coordinates, color="red", label="Unknown CC8 Parameter")

ax.tick_params(axis="both", length=15, direction="inout", color="blue", labelcolor="red")
ax.spines["bottom"].set_color("red")
ax.spines["left"].set_color("red")

# draw legends
ax.legend(loc="lower right", shadow="true", fancybox=True, title="Vehicle Number");
ax.grid("on", alpha=0.9)
# plt.savefig("data/CC8/Scenario 2 generated by marco.png")
# calculate statistacal values
max_accs_cars_scenario2["ACCELERATION"].describe()
# Out:
# count    317.000000
# mean       1.471830
# std        0.615093
# min        0.000000
# 25%        1.500000
# 50%        1.680000
# 75%        1.820000
# max        2.950000
# Name: ACCELERATION, dtype: float64

# %% [markdown]
# Scenario 6 CC8 is 2.5

# %%
# scenario6
vehicle_routes_scenario7 = pd.read_csv("data/Scenarios generated by me/CC8/Scenario7 cc8 is 2point5.csv")
#change the vehicle type from number to name
vehicle_routes_scenario7['VEHTYPE'].replace(to_replace=[100, 150, 200, 300], value=["Car", "Transporter", "HGV", "Bus"],
                                            inplace=True)

all_cars_on_link_54_scenario7 = vehicle_routes_scenario7[
    (vehicle_routes_scenario7["SIMSEC"] < 500) & (
            vehicle_routes_scenario7["SIMSEC"] > 0)]

max_accs_cars_scenario7 = all_cars_on_link_54_scenario7.groupby(["$VEHICLE:NO"]).max()

fig, ax = plt.subplots(figsize=(10, 10))
ax.bar(vehicle_numbers, max_accs_cars_scenario7["ACCELERATION"], label="Vehicle")
ax.set_xlabel("Vehicle numbers", color="red")
ax.set_ylabel("Maximum Acceleration(m/s2)", color="red")
ax.set_title(
    label="Maximum acceleration of all vehicles from standstill position for scenario 7 with unknown CC8 from 0 to 500 seconds",
    color="red")
# draw default CC8
x_coordinates = [0, 318]
y_coordinates = [3.5, 3.5]

ax.plot(x_coordinates, y_coordinates, color="red", label="Unknown CC8 Parameter")

ax.tick_params(axis="both", length=15, direction="inout", color="blue", labelcolor="red")
ax.spines["bottom"].set_color("red")
ax.spines["left"].set_color("red")

# draw legends
ax.legend(loc="lower right", shadow="true", fancybox=True, title="Vehicle Number");
ax.grid("on", alpha=0.9)
# plt.savefig("data/CC8/Scenario 2 generated by marco.png")

# %% [markdown]
# Scenario 8 CC8 is 1.5

# %%
# scenario 8
vehicle_routes_scenario8 = pd.read_csv("data/Scenarios generated by me/CC8/Scenario8 CC8 is 1Point5.csv")
#change the vehicle type from number to name
vehicle_routes_scenario8['VEHTYPE'].replace(to_replace=[100, 150, 200, 300], value=["Car", "Transporter", "HGV", "Bus"],
                                            inplace=True)

all_cars_on_link_54_scenario8 = vehicle_routes_scenario8[
    (vehicle_routes_scenario8["SIMSEC"] < 500) & (
            vehicle_routes_scenario8["SIMSEC"] > 0)]

max_accs_cars_scenario8 = all_cars_on_link_54_scenario8.groupby(["$VEHICLE:NO"]).max()

fig, ax = plt.subplots(figsize=(10, 10))
ax.bar(vehicle_numbers, max_accs_cars_scenario8["ACCELERATION"], label="Vehicle")
ax.set_xlabel("Vehicle numbers", color="red")
ax.set_ylabel("Maximum Acceleration(m/s2)", color="red")
ax.set_title(
    label="Maximum acceleration of all vehicles from standstill position for scenario 8 with CC8 of 1.5 m/sec2",
    color="red")
# draw default CC8
x_coordinates = [0, 318]
y_coordinates = [3.5, 3.5]

ax.plot(x_coordinates, y_coordinates, color="red", label="Unknown CC8 Parameter")

ax.tick_params(axis="both", length=15, direction="inout", color="blue", labelcolor="red")
ax.spines["bottom"].set_color("red")
ax.spines["left"].set_color("red")

# draw legends
ax.legend(loc="lower right", shadow="true", fancybox=True, title="Vehicle Number");
ax.grid("on", alpha=0.9)
# plt.savefig("data/CC8/Scenario 8 cc8 is 1Point5.png")
max_accs_cars_scenario8["ACCELERATION"].describe()
# Out:
# count    317.000000
# mean       1.558580
# std        0.698127
# min        0.000000
# 25%        1.440000
# 50%        1.810000
# 75%        2.010000
# max        2.920000
# Name: ACCELERATION, dtype: float64

# %% [markdown]
# calculating normal distribution

# %%
#https://stackoverflow.com/questions/10138085/how-to-plot-normal-distribution
import scipy.stats as stats
import math

fig, ax = plt.subplots(figsize=(10, 10))
mu_baseline = 1.829
sigma_baseline = 0.947
x_baseline = np.linspace(mu_baseline - 3*sigma_baseline, mu_baseline + 3*sigma_baseline, 100)
line_baseline, =ax.plot(x_baseline, stats.norm.pdf(x_baseline, mu_baseline, sigma_baseline), label="Baseline Scenario")
line_baseline.set_color("red")
ax.legend(loc="lower right", shadow="true", fancybox=True, title="Name of Scenario");

mu_scenario1 = 2.030
sigma_scenario1 = 1.217
x_scenario1 = np.linspace(mu_scenario1 - 3*sigma_scenario1, mu_scenario1 + 3*sigma_scenario1, 100)
line_scenario1, =ax.plot(x_scenario1, stats.norm.pdf(x_scenario1, mu_scenario1, sigma_scenario1), label="Scenario 1")
line_scenario1.set_linestyle("--")
ax.xaxis.grid(True, color="black", linewidth=0.2)
ax.legend(loc="lower right", shadow="true", fancybox=True, title="Name of Scenario");



mu_scenario2 = 1.558
sigma_scenario2 = 0.698
x_scenario2 = np.linspace(mu_scenario2 - 3*sigma_scenario2, mu_scenario2 + 3*sigma_scenario2, 100)
line_scenario2, =ax.plot(x_scenario2, stats.norm.pdf(x_scenario2, mu_scenario2, sigma_scenario2), label="Scenario 2")
line_scenario2.set_linestyle("--")
line_scenario2.set_color("blue")
ax.xaxis.grid(True, color="black", linewidth=0.2)
ax.legend(loc="lower right", shadow="true", fancybox=True, title="Name of Scenario");



plt.xticks(fontsize=10, color="red")
plt.yticks(fontsize=10, color="red")
ax.set_xlabel("Acceleration", fontsize=10, color="red", rotation="45")
ax.set_title(label="The normal distribution for the maximum standstill acceleration of all vehicles in three scenarios",color="red")
# plt.savefig("data/CC8/distributions.png")
# Out:
# Text(0.5, 1.0, 'The normal distribution for the maximum standstill acceleration of all vehicles in three scenarios')

# %% [markdown]
# Scenario 3 generated by Marco

# %%
vehicle_routes_scenario3 = pd.read_csv("data/Scenarios generated by Marco/GothaerPlatz - Scenario 3.csv")
#change the vehicle type from number to name
vehicle_routes_scenario3['VEHTYPE'].replace(to_replace=[100, 150, 200, 300], value=["Car", "Transporter", "HGV", "Bus"],
                                            inplace=True)

all_cars_on_link_54_scenario3 = vehicle_routes_scenario3[
    (vehicle_routes_scenario3["SIMSEC"] < 500) & (
            vehicle_routes_scenario3["SIMSEC"] > 0)]

max_accs_cars_scenario3 = all_cars_on_link_54_scenario3.groupby(["$VEHICLE:NO"]).max()

fig, ax = plt.subplots(figsize=(10, 10))
ax.bar(vehicle_numbers, max_accs_cars_scenario3["ACCELERATION"], label="Vehicle")
ax.set_xlabel("Vehicle numbers", color="red")
ax.set_ylabel("Maximum Acceleration(m/s2)", color="red")
ax.set_title(
    label="Maximum acceleration of all vehicles from standstill position for scenario 8 with CC8 of 1.5 m/sec2",
    color="red")
# draw default CC8
x_coordinates = [0, 318]
y_coordinates = [3.5, 3.5]

ax.plot(x_coordinates, y_coordinates, color="red", label="Unknown CC8 Parameter")

ax.tick_params(axis="both", length=15, direction="inout", color="blue", labelcolor="red")
ax.spines["bottom"].set_color("red")
ax.spines["left"].set_color("red")

# draw legends
ax.legend(loc="lower right", shadow="true", fancybox=True, title="Vehicle Number");
ax.grid("on", alpha=0.9)
# plt.savefig("data/CC8/Scenario 3 cc8 is random.png")
max_accs_cars_scenario3["ACCELERATION"].describe()
cc8 = max_accs_cars_scenario3["ACCELERATION"].max()
print(f"The value of CC8 is approximately {cc8}")
# Out:
# The value of CC8 is approximately 3.25
